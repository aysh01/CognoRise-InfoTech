# %% [markdown]
# <h1>Step 1: Load the Data</h1>

# %% [markdown]
# <h2>First, load the train and test datasets.</h2>

# %%
# from google.colab import files
# a=files.upload()
# b=files.upload()
# Out:
#      <input type="file" id="files-969d748a-590c-4845-8d37-64d3c5077232" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-969d748a-590c-4845-8d37-64d3c5077232">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
# import io
# train_df=pd.read_csv(io.StringIO(a['train.csv'].decode('utf-8')))
# test_df=pd.read_csv(io.StringIO(b['test.csv'].decode('utf-8')))
train_df=pd.read_csv('https://raw.githubusercontent.com/aysh01/CognoRise-InfoTech/main/Hackathon/Data-Science-Hackathon/train.csv')
test_df=pd.read_csv('https://raw.githubusercontent.com/aysh01/CognoRise-InfoTech/main/Hackathon/Data-Science-Hackathon/test.csv')

# %% [markdown]
# <hr>

# %% [markdown]
# <h1>Train Dataset</h1>

# %%
train_df
# Out:
#          Roll no test preparation   gender parental level of education  \
# 0      EXA000001              none    male                some college
# 1      EXA000002              none    male             master's degree
# 2      EXA000003              none    male             master's degree
# 3      EXA000004              none  female                some college
# 4      EXA000005              none  female                 high school
# ...          ...               ...     ...                         ...
# 31994  EXA031995              none    male            some high school
# 31995  EXA031996              none  female                 high school
# 31996  EXA031997              none    male           bachelor's degree
# 31997  EXA031998              none    male          associate's degree
# 31998  EXA031999              none    male            some high school
#
#               lunch    Section  practical score  viva score  exam score
# ...

# %% [markdown]
# <hr>

# %% [markdown]
# <h1>Test Dataset</h1>

# %%
test_df
# Out:
#      Roll no test preparation   gender parental level of education  \
# 0   EXA32000              none    male          associate's degree
# 1   EXA32001         completed    male            some high school
# 2   EXA32002              none    male            some high school
# 3   EXA32003         completed    male            some high school
# 4   EXA32004              none  female           bachelor's degree
# ..       ...               ...     ...                         ...
# 95  EXA32095              none    male           bachelor's degree
# 96  EXA32096         completed    male          associate's degree
# 97  EXA32097              none    male                some college
# 98  EXA32098         completed    male          associate's degree
# 99  EXA32099              none    male                 high school
#
#            lunch    Section  practical score  viva score
# 0       standard  Section C               74          89
# ...

# %% [markdown]
# <hr>

# %% [markdown]
# <h2>Explore the Data.</h2<

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31999 entries, 0 to 31998
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Roll no                      31999 non-null  object
#  1   test preparation             31999 non-null  object
#  2   gender                       31999 non-null  object
#  3   parental level of education  31999 non-null  object
#  4   lunch                        31999 non-null  object
#  5   Section                      31999 non-null  object
#  6   practical score              31999 non-null  int64
#  7   viva score                   31999 non-null  int64
#  8   exam score                   31999 non-null  int64
# dtypes: int64(3), object(6)
# memory usage: 2.2+ MB

# %% [markdown]
# <h2>
# *   Since, here. The, target column has Integer datatype. So, we'll convert it to float datatype. So, we can use it to train our model.
# </h2>

# %%
train_df['exam score'] = train_df['exam score'].astype(float)

# %% [markdown]
# <hr><hr>

# %% [markdown]
# <h1>Step 2: Data Preprocessing</h2>

# %% [markdown]
# <h2>•Preprocess the data by encoding categorical variables and handling missing values if necessary.</h2>

# %% [markdown]
# <hr>

# %% [markdown]
# <h3>1. Remove extra spaces from column names:</h3>

# %%
train_df.columns = train_df.columns.str.strip()
test_df.columns = test_df.columns.str.strip()

# %% [markdown]
# <hr>

# %% [markdown]
# <h2>2. Align the columns of the test set with the train set:</h2>

# %%
X_train = train_df.drop(columns=['Roll no','exam score'])
y_train = train_df['exam score']

X_test = train_df.drop(['Roll no'],axis=1)

missing_cols = set(X_train.columns) - set(X_test.columns)
for c in missing_cols:
    X_test[c] = 0

X_test = X_test[X_train.columns]

# %% [markdown]
# <hr><hr>

# %% [markdown]
# <h1>Step 3: Train a Simple Linear Regression Model</h1>

# %%
X_train.drop(columns=['test preparation'],inplace=True)

# %%
col
# Out:
# Index(['parental level of education', 'lunch', 'Section'], dtype='object')

# %%
gender=['male','female']
age=['1','0']
X_train.replace(gender,age,inplace=True)
X_train.drop(columns=['parental level of education','lunch','Section'],inplace=True)
X_train
# Out:
#       gender  practical score  viva score
# 0          1               70          73
# 1          1               55          54
# 2          1               56          46
# 3          0               35          47
# 4          0               87          92
# ...      ...              ...         ...
# 31994      1               63          53
# 31995      0              100          80
# 31996      1               62          61
# 31997      1               75          32
# 31998      1               51          92
#
# [31999 rows x 3 columns]

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

X_train,X_test,y_train,y_test = train_test_split(X_train,y_train,test_size=0.2,random_state=42)

randomForest = RandomForestRegressor(n_estimators=100,random_state=42)
randomForest.fit(X_train,y_train)

predict = randomForest.predict(X_test)
mse = mean_squared_error(y_test, predict)
r2 = r2_score(y_test, predict)

print(f"Mean Squared Error: {mse}")
print(f"R^2 Score: {r2}")
# Out:
# Mean Squared Error: 261.67939439922947
# R^2 Score: -0.172025270475354

# %%
from sklearn.linear_model import LinearRegression

model= LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# <hr><hr>

# %% [markdown]
# <h1>Step 4: Predict the Exam Scores for the Test Dataset</h1>

# %%
predict_test = model.predict(X_test)
predict_test
# Out:
# array([69.06432625, 69.06515135, 68.55612041, ..., 68.60430988,
#        69.81663939, 69.50712842])

# %% [markdown]
# <hr><hr>

# %% [markdown]
# <h1>Step 5: Create the Submission File</h1>

# %%
df_1 = pd.DataFrame({'Roll no':test_df['Roll no'],
                     'Exam score': pd.Series(predict_test[:100])})
df_1
# Out:
#      Roll no  Exam score
# 0   EXA32000   69.064326
# 1   EXA32001   69.065151
# 2   EXA32002   68.556120
# 3   EXA32003   69.413623
# 4   EXA32004   68.796702
# ..       ...         ...
# 95  EXA32095   69.528319
# 96  EXA32096   69.004904
# 97  EXA32097   68.927936
# 98  EXA32098   68.578092
# 99  EXA32099   69.215657
#
# [100 rows x 2 columns]

# %% [markdown]
# <h2>Saving the File as 'submission.csv' in the local path.</h2>

# %%
df_1.to_csv(r'submission.csv')

# %% [markdown]
# <h1>CognoRise InfoTech Data Science Hackathon.</h1>

# %% [markdown]
# <hr><hr>
